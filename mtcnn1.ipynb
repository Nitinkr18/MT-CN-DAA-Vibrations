# %%
import os
import pandas as pd
import numpy as np
import scipy.io
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv2D, MaxPooling2D, Flatten, Dense, GlobalAveragePooling2D, 
    Reshape, multiply, add, Activation, Lambda, Concatenate, Dropout
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

print("TensorFlow Version:", tf.__version__)

# --- Configuration ---
DATASET_PATH = 'D:/challa' 
IMG_SIZE = 128
BATCH_SIZE = 32
EPOCHS = 100
LEARNING_RATE = 0.0005

# --- 1. Data Loading ---
def parse_filenames_to_dataframe(dataset_path):
    records = []
    expanded_path = os.path.expanduser(dataset_path)
    print(f"Scanning main directory: {expanded_path}...")

    if not os.path.isdir(expanded_path):
        print(f"Error: Directory not found. Check DATASET_PATH.")
        return pd.DataFrame()

    bearing_dirs = [d for d in os.listdir(expanded_path) 
                    if os.path.isdir(os.path.join(expanded_path, d)) and not d.startswith('.')]
    print(f"Found bearing type folders: {bearing_dirs}")
    
    for bearing_type in bearing_dirs:
        bearing_path = os.path.join(expanded_path, bearing_type)
        for root, _, files in os.walk(bearing_path):
            for file in files:
                if file.endswith('.mat'):
                    file_parts = file.replace('.mat', '').split('_')
                    if len(file_parts) == 5:
                        speed = int(file_parts[4])
                        records.append({
                            'filepath': os.path.join(root, file),
                            'filename': file,
                            'speed': speed
                        })
    
    df = pd.DataFrame(records)
    print(f"Scan complete. Found {len(df)} total .mat files.")
    return df

# --- 2. Label Processing ---
def process_labels(df):
    print("\nProcessing labels for joint classification and domain adaptation...")
    
    df['joint_code'] = df['filename'].apply(lambda f: f.split('_')[0] + '_' + f.split('_')[1])
    df['joint_label'], joint_classes = pd.factorize(df['joint_code'])
    
    df['domain_label'], domain_classes = pd.factorize(df['speed'])
    
    print("Label processing complete.")
    print(f"Found {len(joint_classes)} unique joint conditions.")
    print(f"Found {len(domain_classes)} unique domains (speeds).")
    
    return df, list(domain_classes), list(joint_classes)

# --- 3. Data Pipeline ---
def load_and_process_file(filepath, joint_label, domain_label):
    mat_contents = scipy.io.loadmat(filepath.numpy())
    spectrogram_data = mat_contents['Spectrogram'].astype(np.float32)
    
    if np.max(spectrogram_data) > 0:
        spectrogram_data = spectrogram_data / np.max(spectrogram_data)
    
    images = np.expand_dims(spectrogram_data, axis=-1)
    
    num_samples = images.shape[0]
    
    joint_labels = to_categorical([joint_label] * num_samples, num_classes=32)
    domain_labels = to_categorical([domain_label] * num_samples, num_classes=6)
    
    return images, joint_labels, domain_labels

def tf_load_and_process(filepath, labels):
    images, j_labels, d_labels = tf.py_function(
        func=load_and_process_file,
        inp=[filepath, labels['joint'], labels['domain']],
        Tout=(tf.float32, tf.float32, tf.float32)
    )
    
    images.set_shape([None, IMG_SIZE, IMG_SIZE, 1])
    j_labels.set_shape([None, 32])
    d_labels.set_shape([None, 6])
    
    labels_dict = {
        "joint_output": j_labels,
        "domain_output": d_labels
    }
    
    return tf.data.Dataset.from_tensor_slices((images, labels_dict))

# --- 4. Model Architecture ---
@tf.custom_gradient
def grad_reverse(x, lambda_val=1.0):
    y = tf.identity(x)
    def custom_grad(dy):
        return -lambda_val * dy, None
    return y, custom_grad

class GradientReversal(tf.keras.layers.Layer):
    def __init__(self, lambda_val=1.0):
        super().__init__()
        self.lambda_val = lambda_val

    def call(self, x):
        return grad_reverse(x, self.lambda_val)

def cbam_module(x, ratio=8):
    channels = x.shape[-1]
    avg_pool = GlobalAveragePooling2D()(x)
    max_pool = tf.keras.layers.GlobalMaxPooling2D()(x)
    shared_dense_one = Dense(channels // ratio, activation='relu')
    shared_dense_two = Dense(channels)
    avg_out = shared_dense_two(shared_dense_one(avg_pool))
    max_out = shared_dense_two(shared_dense_one(max_pool))
    channel_attention = Activation('sigmoid')(add([avg_out, max_out]))
    channel_attention = Reshape((1, 1, channels))(channel_attention)
    x_channel = multiply([x, channel_attention])
    avg_pool_spatial = Lambda(lambda y: tf.reduce_mean(y, axis=3, keepdims=True))(x_channel)
    max_pool_spatial = Lambda(lambda y: tf.reduce_max(y, axis=3, keepdims=True))(x_channel)
    concat = Concatenate(axis=3)([avg_pool_spatial, max_pool_spatial])
    spatial_attention = Conv2D(1, (7, 7), padding='same', activation='sigmoid')(concat)
    return multiply([x_channel, spatial_attention])

def build_efficient_model(input_shape=(128, 128, 1)):
    inputs = Input(shape=input_shape, name='input')
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)
    x = cbam_module(x, ratio=8)
    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)
    features = Flatten()(x)
    features = Dropout(0.5)(features)
    
    joint_head = Dense(256, activation='relu')(features)
    joint_head = Dropout(0.3)(joint_head)
    joint_output = Dense(32, activation='softmax', name='joint_output')(joint_head)
    
    domain_features = GradientReversal(lambda_val=0.5)(features)
    domain_head = Dense(128, activation='relu')(domain_features)
    domain_output = Dense(6, activation='softmax', name='domain_output')(domain_head)
    
    model = Model(inputs=inputs, outputs=[joint_output, domain_output])
    return model

# --- 5. Main Execution ---
if __name__ == "__main__":
    master_df = parse_filenames_to_dataframe(DATASET_PATH)
    
    if not master_df.empty:
        master_df, domain_classes, joint_classes = process_labels(master_df)
        
        train_df, val_df = train_test_split(
            master_df, test_size=0.2, random_state=42, stratify=master_df['joint_label']
        )
        print(f"\nTrain samples: {len(train_df)}")
        print(f"Validation samples: {len(val_df)}")
        
        # Create a dataset of filepaths and labels
        train_labels_ds = tf.data.Dataset.from_tensor_slices({
            'joint': train_df['joint_label'].values, 
            'domain': train_df['domain_label'].values
        })
        train_filepaths_ds = tf.data.Dataset.from_tensor_slices(train_df['filepath'].values)
        train_ds = tf.data.Dataset.zip((train_filepaths_ds, train_labels_ds))
        
        # Build the final, correct training pipeline
        train_dataset = train_ds.shuffle(buffer_size=len(train_df))
        train_dataset = train_dataset.flat_map(tf_load_and_process)
        train_dataset = train_dataset.shuffle(buffer_size=10000)
        train_dataset = train_dataset.repeat() # <-- FIX IS HERE
        train_dataset = train_dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
        
        # Build the final validation pipeline
        val_labels_ds = tf.data.Dataset.from_tensor_slices({
            'joint': val_df['joint_label'].values, 
            'domain': val_df['domain_label'].values
        })
        val_filepaths_ds = tf.data.Dataset.from_tensor_slices(val_df['filepath'].values)
        val_ds = tf.data.Dataset.zip((val_filepaths_ds, val_labels_ds))
        
        val_dataset = val_ds.flat_map(tf_load_and_process)
        val_dataset = val_dataset.repeat() # <-- AND FIX IS HERE
        val_dataset = val_dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
        
        print("\n Data pipelines created successfully.")
        
        model = build_efficient_model()
        model.compile(
            optimizer=Adam(learning_rate=LEARNING_RATE),
            loss={'joint_output': 'categorical_crossentropy', 'domain_output': 'categorical_crossentropy'},
            loss_weights={'joint_output': 1.0, 'domain_output': 0.1},
            metrics={'joint_output': 'accuracy', 'domain_output': 'accuracy'}
        )
        model.summary()
        
        callbacks = [
            EarlyStopping(monitor='val_joint_output_accuracy', mode='max', patience=10, restore_best_weights=True, verbose=1),
            ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6, verbose=1)
        ]
        
        # Calculate steps per epoch
        train_steps = len(train_df) * 78 // BATCH_SIZE
        val_steps = len(val_df) * 78 // BATCH_SIZE
        print(f"\nTraining steps per epoch: {train_steps}")
        print(f"Validation steps per epoch: {val_steps}")
        
        # Train the model
        print("\n--- Starting Model Training ---")
        history = model.fit(
            train_dataset,
            validation_data=val_dataset,
            epochs=EPOCHS,
            steps_per_epoch=train_steps,
            validation_steps=val_steps,
            callbacks=callbacks,
            verbose=1
        )
        
        print("\n Model training complete!")
        
        # Final Evaluation
        print("\n--- Final Model Evaluation ---")
        results = model.evaluate(val_dataset, steps=val_steps, verbose=0)
        
        model.save('efficient_mt_cnn_da_model.h5')
        print("\nModel saved as 'efficient_mt_cnn_da_model.h5'")
# Out:
# TensorFlow Version: 2.20.0
# Scanning main directory: D:/challa...
# Found bearing type folders: ['1', '2', '3']
# Scan complete. Found 1149 total .mat files.
#
# Processing labels for joint classification and domain adaptation...
# Label processing complete.
# Found 32 unique joint conditions.
# Found 6 unique domains (speeds).
#
# Train samples: 919
# Validation samples: 230
#
#  Data pipelines created successfully.
# WARNING:tensorflow:From c:\Users\yeshx\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 128, 128,  │          0 │ -                 │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │        320 │ input[0][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 64, 64,    │          0 │ conv2d[0][0]      │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 64, 64,    │     18,496 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 32, 32,    │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ max_pooling2d_1[… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 64)        │          0 │ max_pooling2d_1[… │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 8)         │        520 │ global_average_p… │
# │                     │                   │            │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │        576 │ dense[0][0],      │
# │                     │                   │            │ dense[1][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 64)        │          0 │ dense_1[0][0],    │
# │                     │                   │            │ dense_1[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 64)        │          0 │ add[0][0]         │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 1, 64)  │          0 │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 32, 32,    │          0 │ max_pooling2d_1[… │
# │                     │ 64)               │            │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 32, 32, 1) │          0 │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_1 (Lambda)   │ (None, 32, 32, 1) │          0 │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32, 2) │          0 │ lambda[0][0],     │
# │ (Concatenate)       │                   │            │ lambda_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 32, 32, 1) │         99 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 32, 32,    │          0 │ multiply[0][0],   │
# │ (Multiply)          │ 64)               │            │ conv2d_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 32, 32,    │     73,856 │ multiply_1[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 16, 16,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 16, 16,    │    295,168 │ max_pooling2d_2[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 8, 8, 256) │          0 │ conv2d_4[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 16384)     │          0 │ max_pooling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 16384)     │          0 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 256)       │  4,194,560 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gradient_reversal   │ (None, 16384)     │          0 │ dropout[0][0]     │
# │ (GradientReversal)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 256)       │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 128)       │  2,097,280 │ gradient_reversa… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ joint_output        │ (None, 32)        │      8,224 │ dropout_1[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ domain_output       │ (None, 6)         │        774 │ dense_3[0][0]     │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 6,689,873 (25.52 MB)
#  Trainable params: 6,689,873 (25.52 MB)
#  Non-trainable params: 0 (0.00 B)
# Training steps per epoch: 2240
# Validation steps per epoch: 560
#
# --- Starting Model Training ---
# Epoch 1/100
# 2240/2240 ━━━━━━━━━━━━━━━━━━━━ 615s 266ms/step - domain_output_accuracy: 0.7083 - domain_output_loss: 0.7409 - joint_output_accuracy: 0.5886 - joint_output_loss: 1.2428 - loss: 1.3169 - val_domain_output_accuracy: 0.5746 - val_domain_output_loss: 1.4396 - val_joint_output_accuracy: 0.4172 - val_joint_output_loss: 2.0326 - val_loss: 2.1766 - learning_rate: 5.0000e-04
# Epoch 2/100
# 2240/2240 ━━━━━━━━━━━━━━━━━━━━ 677s 302ms/step - domain_output_accuracy: 0.8975 - domain_output_loss: 0.2797 - joint_output_accuracy: 0.8194 - joint_output_loss: 0.4955 - loss: 0.5234 - val_domain_output_accuracy: 0.5599 - val_domain_output_loss: 1.7169 - val_joint_output_accuracy: 0.5014 - val_joint_output_loss: 1.9669 - val_loss: 2.1386 - learning_rate: 5.0000e-04
# Epoch 3/100
# 2240/2240 ━━━━━━━━━━━━━━━━━━━━ 631s 282ms/step - domain_output_accuracy: 0.9345 - domain_output_loss: 0.1811 - joint_output_accuracy: 0.8726 - joint_output_loss: 0.3469 - loss: 0.3650 - val_domain_output_accuracy: 0.6137 - val_domain_output_loss: 1.5232 - val_joint_output_accuracy: 0.5119 - val_joint_output_loss: 1.8219 - val_loss: 1.9742 - learning_rate: 5.0000e-04
# Epoch 4/100
# 2240/2240 ━━━━━━━━━━━━━━━━━━━━ 682s 305ms/step - domain_output_accuracy: 0.9518 - domain_output_loss: 0.1356 - joint_output_accuracy: 0.8976 - joint_output_loss: 0.2796 - loss: 0.2932 - val_domain_output_accuracy: 0.6022 - val_domain_output_loss: 1.7411 - val_joint_output_accuracy: 0.5001 - val_joint_output_loss: 2.0980 - val_loss: 2.2721 - learning_rate: 5.0000e-04
# Epoch 5/100
# 2240/2240 ━━━━━━━━━━━━━━━━━━━━ 629s 281ms/step - domain_output_accuracy: 0.9598 - domain_output_loss: 0.1113 - joint_output_accuracy: 0.9129 - joint_output_loss: 0.2344 - loss: 0.2455 - val_domain_output_accuracy: 0.6110 - val_domain_output_loss: 1.8945 - val_joint_output_accuracy: 0.5151 - val_joint_output_loss: 2.2256 - val_loss: 2.4151 - learning_rate: 5.0000e-04
# Epoch 6/100
# 2240/2240 ━━━━━━━━━━━━━━━━━━━━ 536s 239ms/step - domain_output_accuracy: 0.9682 - domain_output_loss: 0.0924 - joint_output_accuracy: 0.9293 - joint_output_loss: 0.1953 - loss: 0.2045 - val_domain_output_accuracy: 0.6287 - val_domain_output_loss: 1.8200 - val_joint_output_accuracy: 0.5116 - val_joint_output_loss: 2.5800 - val_loss: 2.7620 - learning_rate: 5.0000e-04
# Epoch 7/100
# 2240/2240 ━━━━━━━━━━━━━━━━━━━━ 359s 160ms/step - domain_output_accuracy: 0.9734 - domain_output_loss: 0.0764 - joint_output_accuracy: 0.9365 - joint_output_loss: 0.1744 - loss: 0.1820 - val_domain_output_accuracy: 0.6425 - val_domain_output_loss: 1.7817 - val_joint_output_accuracy: 0.5247 - val_joint_output_loss: 2.5106 - val_loss: 2.6888 - learning_rate: 5.0000e-04
# Epoch 8/100
# 2240/2240 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - domain_output_accuracy: 0.9767 - domain_output_loss: 0.0660 - joint_output_accuracy: 0.9503 - joint_output_loss: 0.1380 - loss: 0.1446
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 2240/2240 ━━━━━━━━━━━━━━━━━━━━ 355s 158ms/step - domain_output_accuracy: 0.9764 - domain_output_loss: 0.0675 - joint_output_accuracy: 0.9432 - joint_output_loss: 0.1560 - loss: 0.1628 - val_domain_output_accuracy: 0.6348 - val_domain_output_loss: 1.6522 - val_joint_output_accuracy: 0.5367 - val_joint_output_loss: 2.4312 - val_loss: 2.5965 - learning_rate: 5.0000e-04
# Epoch 9/100
# 2240/2240 ━━━━━━━━━━━━━━━━━━━━ 358s 160ms/step - domain_output_accuracy: 0.9874 - domain_output_loss: 0.0387 - joint_output_accuracy: 0.9584 - joint_output_loss: 0.1129 - loss: 0.1168 - val_domain_output_accuracy: 0.6607 - val_domain_output_loss: 1.9054 - val_joint_output_accuracy: 0.5398 - val_joint_output_loss: 2.6684 - val_loss: 2.8589 - learning_rate: 1.0000e-04
# Epoch 10/100
# 2240/2240 ━━━━━━━━━━━━━━━━━━━━ 356s 159ms/step - domain_output_accuracy: 0.9917 - domain_output_loss: 0.0248 - joint_output_accuracy: 0.9679 - joint_output_loss: 0.0850 - loss: 0.0875 - val_domain_output_accuracy: 0.6561 - val_domain_output_loss: 2.0219 - val_joint_output_accuracy: 0.5553 - val_joint_output_loss: 2.9014 - val_loss: 3.1036 - learning_rate: 1.0000e-04
# Epoch 11/100
# 2240/2240 ━━━━━━━━━━━━━━━━━━━━ 518s 231ms/step - domain_output_accuracy: 0.9928 - domain_output_loss: 0.0212 - joint_output_accuracy: 0.9716 - joint_output_loss: 0.0753 - loss: 0.0775 - val_domain_output_accuracy: 0.6553 - val_domain_output_loss: 2.0628 - val_joint_output_accuracy: 0.5508 - val_joint_output_loss: 2.9439 - val_loss: 3.1501 - learning_rate: 1.0000e-04
# Epoch 12/100
# 2240/2240 ━━━━━━━━━━━━━━━━━━━━ 386s 172ms/step - domain_output_accuracy: 0.9933 - domain_output_loss: 0.0187 - joint_output_accuracy: 0.9750 - joint_output_loss: 0.0677 - loss: 0.0695 - val_domain_output_accuracy: 0.6657 - val_domain_output_loss: 2.1596 - val_joint_output_accuracy: 0.5525 - val_joint_output_loss: 2.9177 - val_loss: 3.1337 - learning_rate: 1.0000e-04
# Epoch 13/100
# 2240/2240 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - domain_output_accuracy: 0.9936 - domain_output_loss: 0.0183 - joint_output_accuracy: 0.9751 - joint_output_loss: 0.0640 - loss: 0.0658
# Epoch 13: ReduceLROnPlateau reducing learning rate to 2.0000000949949027e-05.
# 2240/2240 ━━━━━━━━━━━━━━━━━━━━ 454s 203ms/step - domain_output_accuracy: 0.9939 - domain_output_loss: 0.0177 - joint_output_accuracy: 0.9764 - joint_output_loss: 0.0624 - loss: 0.0641 - val_domain_output_accuracy: 0.6682 - val_domain_output_loss: 2.1732 - val_joint_output_accuracy: 0.5592 - val_joint_output_loss: 3.1335 - val_loss: 3.3508 - learning_rate: 1.0000e-04
# Epoch 14/100
# 2240/2240 ━━━━━━━━━━━━━━━━━━━━ 566s 253ms/step - domain_output_accuracy: 0.9953 - domain_output_loss: 0.0148 - joint_output_accuracy: 0.9752 - joint_output_loss: 0.0651 - loss: 0.0666 - val_domain_output_accuracy: 0.6593 - val_domain_output_loss: 2.2129 - val_joint_output_accuracy: 0.5502 - val_joint_output_loss: 3.1482 - val_loss: 3.3695 - learning_rate: 2.0000e-05
# Epoch 15/100
# 2240/2240 ━━━━━━━━━━━━━━━━━━━━ 497s 222ms/step - domain_output_accuracy: 0.9959 - domain_output_loss: 0.0120 - joint_output_accuracy: 0.9782 - joint_output_loss: 0.0563 - loss: 0.0575 - val_domain_output_accuracy: 0.6700 - val_domain_output_loss: 2.2119 - val_joint_output_accuracy: 0.5536 - val_joint_output_loss: 3.2469 - val_loss: 3.4681 - learning_rate: 2.0000e-05
# Epoch 16/100
# 2240/2240 ━━━━━━━━━━━━━━━━━━━━ 502s 224ms/step - domain_output_accuracy: 0.9962 - domain_output_loss: 0.0112 - joint_output_accuracy: 0.9787 - joint_output_loss: 0.0556 - loss: 0.0568 - val_domain_output_accuracy: 0.6707 - val_domain_output_loss: 2.2327 - val_joint_output_accuracy: 0.5459 - val_joint_output_loss: 3.3264 - val_loss: 3.5497 - learning_rate: 2.0000e-05
# Epoch 17/100
# 2240/2240 ━━━━━━━━━━━━━━━━━━━━ 515s 230ms/step - domain_output_accuracy: 0.9961 - domain_output_loss: 0.0112 - joint_output_accuracy: 0.9803 - joint_output_loss: 0.0527 - loss: 0.0539 - val_domain_output_accuracy: 0.6675 - val_domain_output_loss: 2.2956 - val_joint_output_accuracy: 0.5465 - val_joint_output_loss: 3.4368 - val_loss: 3.6663 - learning_rate: 2.0000e-05
# Epoch 18/100
# 2240/2240 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - domain_output_accuracy: 0.9964 - domain_output_loss: 0.0112 - joint_output_accuracy: 0.9814 - joint_output_loss: 0.0498 - loss: 0.0510
# Epoch 18: ReduceLROnPlateau reducing learning rate to 4.000000262749381e-06.
# 2240/2240 ━━━━━━━━━━━━━━━━━━━━ 685s 306ms/step - domain_output_accuracy: 0.9967 - domain_output_loss: 0.0104 - joint_output_accuracy: 0.9812 - joint_output_loss: 0.0507 - loss: 0.0518 - val_domain_output_accuracy: 0.6617 - val_domain_output_loss: 2.4119 - val_joint_output_accuracy: 0.5503 - val_joint_output_loss: 3.4259 - val_loss: 3.6671 - learning_rate: 2.0000e-05
# Epoch 19/100
# 2240/2240 ━━━━━━━━━━━━━━━━━━━━ 501s 224ms/step - domain_output_accuracy: 0.9964 - domain_output_loss: 0.0106 - joint_output_accuracy: 0.9801 - joint_output_loss: 0.0530 - loss: 0.0540 - val_domain_output_accuracy: 0.6711 - val_domain_output_loss: 2.3218 - val_joint_output_accuracy: 0.5535 - val_joint_output_loss: 3.3526 - val_loss: 3.5848 - learning_rate: 4.0000e-06
# Epoch 20/100
# 2240/2240 ━━━━━━━━━━━━━━━━━━━━ 376s 168ms/step - domain_output_accuracy: 0.9964 - domain_output_loss: 0.0103 - joint_output_accuracy: 0.9812 - joint_output_loss: 0.0501 - loss: 0.0511 - val_domain_output_accuracy: 0.6695 - val_domain_output_loss: 2.3281 - val_joint_output_accuracy: 0.5529 - val_joint_output_loss: 3.3935 - val_loss: 3.6263 - learning_rate: 4.0000e-06
# Epoch 21/100
# 2240/2240 ━━━━━━━━━━━━━━━━━━━━ 374s 167ms/step - domain_output_accuracy: 0.9965 - domain_output_loss: 0.0103 - joint_output_accuracy: 0.9815 - joint_output_loss: 0.0496 - loss: 0.0506 - val_domain_output_accuracy: 0.6735 - val_domain_output_loss: 2.3366 - val_joint_output_accuracy: 0.5547 - val_joint_output_loss: 3.3648 - val_loss: 3.5984 - learning_rate: 4.0000e-06
# Epoch 22/100
# 2240/2240 ━━━━━━━━━━━━━━━━━━━━ 477s 213ms/step - domain_output_accuracy: 0.9966 - domain_output_loss: 0.0101 - joint_output_accuracy: 0.9818 - joint_output_loss: 0.0475 - loss: 0.0485 - val_domain_output_accuracy: 0.6701 - val_domain_output_loss: 2.3566 - val_joint_output_accuracy: 0.5537 - val_joint_output_loss: 3.4140 - val_loss: 3.6496 - learning_rate: 4.0000e-06
# Epoch 23/100
# 2240/2240 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - domain_output_accuracy: 0.9976 - domain_output_loss: 0.0077 - joint_output_accuracy: 0.9830 - joint_output_loss: 0.0456 - loss: 0.0464
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1e-06.
# 2240/2240 ━━━━━━━━━━━━━━━━━━━━ 651s 291ms/step - domain_output_accuracy: 0.9970 - domain_output_loss: 0.0095 - joint_output_accuracy: 0.9816 - joint_output_loss: 0.0484 - loss: 0.0493 - val_domain_output_accuracy: 0.6741 - val_domain_output_loss: 2.3377 - val_joint_output_accuracy: 0.5528 - val_joint_output_loss: 3.4111 - val_loss: 3.6449 - learning_rate: 4.0000e-06
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
#
#  Model training complete!
#
# --- Final Model Evaluation ---
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Final Performance Metrics:
# Total Loss: 3.3508
# Joint Classification Loss: 3.1335
# Domain Head Loss: 2.1732
# Joint Classification Accuracy: 66.82%
# Domain Head Accuracy: 55.92% (Note: Lower is better)
#
# Model saved as 'efficient_mt_cnn_da_model.h5'
